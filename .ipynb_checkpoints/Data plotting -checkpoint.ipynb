# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
sales = pd.read_csv('C:\\Users\\fardi\\OneDrive\\Desktop\\10000 Sales Records.csv',index_col=None, 
            skip_blank_lines=True, 
            na_filter=True )
sales.info
# Out:
# <bound method DataFrame.info of                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
sales.describe

# %%
sales['Unit Cost'].describe()

# %%
sales.head(5)

# %%
sales.tail(6)

# %%
sales.shape

# %%
sales['Unit Cost'].mean()

# %%
sales['Unit Cost'].median()

# %%
sales['Unit Cost'].plot(kind='density',figsize= (14,6))

# %%
sales['Unit Cost'].plot(kind='hist',figsize= (14,6), color= 'green')

# %%
ax= sales['Unit Cost'].plot(kind='density',figsize= (14,6))

# %%
ax= sales['Unit Cost'].plot(kind='density',figsize= (14,6))
ax.set_xlabel('Total money')
ax.set_ylabel('Number of sales')

# %%
sales['Unit Cost'].plot(kind='pie',figsize= (6,6))

# %%
sales['Units Sold'].describe()
# Out:
# count    10000.000000
# mean      5002.855900
# std       2873.246454
# min          2.000000
# 25%       2530.750000
# 50%       4962.000000
# 75%       7472.000000
# max      10000.000000
# Name: Units Sold, dtype: float64

# %%
sales['Units Sold'].plot(kind='pie',figsize= (6,6))
# Out:
# <AxesSubplot:ylabel='Units Sold'>

# %%
sales['Units Sold'].value_counts().plot(kind='pie',figsize= (6,6)) #color= 'green')
# Out:
# <AxesSubplot:ylabel='Units Sold'>

# %%
sales['Units Sold'].value_counts()
# Out:
# 1770    6
# 5721    6
# 4526    6
# 788     6
# 4659    6
#        ..
# 7016    1
# 9063    1
# 7008    1
# 9055    1
# 2047    1
# Name: Units Sold, Length: 6307, dtype: int64

# %%
ax2 =sales['Units Sold'].value_counts().plot(kind='density',figsize= (14,6), color= 'green')

ax2.set_xlabel("Price")
ax2.set_ylabel("Number")
#ax2.axvline(sales['Units Sold'].mean() , color='Red')
# Out:
# Text(0, 0.5, 'Number')
