# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
sales = pd.read_csv('C:\\Users\\fardi\\OneDrive\\Desktop\\Bayof Bengal Temp and time.csv',index_col=None, 
            skip_blank_lines=True, 
            na_filter=True )
sales.info
# Out:
# <bound method DataFrame.info of     Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  \
# 0          Teknaf  1977      1      30.9      15.6         0
# 1          Teknaf  1978      1      30.0      13.1         0
# 2          Teknaf  1979      1      31.7      14.9         0
# 3          Teknaf  1980      1      29.2      15.4         0
# 4          Teknaf  1981      1      29.5      16.0        15
# ..            ...   ...    ...       ...       ...       ...
# 439        Teknaf  2009     12      30.3      16.5         0
# 440        Teknaf  2010     12      31.7      16.7       193
# 441        Teknaf  2011     12      31.5      16.4         0
# 442        Teknaf  2012     12      30.0      15.8         0
# 443        Teknaf  2013     12      29.9      16.5         0
#
#      Relative Humidity  Wind Speed  Cloud Coverage  Bright Sunshine  \
# 0                   60         1.5             0.3              9.7
# ...

# %%
sales.describe
# Out:
# <bound method NDFrame.describe of     Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  \
# 0          Teknaf  1977      1      30.9      15.6         0
# 1          Teknaf  1978      1      30.0      13.1         0
# 2          Teknaf  1979      1      31.7      14.9         0
# 3          Teknaf  1980      1      29.2      15.4         0
# 4          Teknaf  1981      1      29.5      16.0        15
# ..            ...   ...    ...       ...       ...       ...
# 439        Teknaf  2009     12      30.3      16.5         0
# 440        Teknaf  2010     12      31.7      16.7       193
# 441        Teknaf  2011     12      31.5      16.4         0
# 442        Teknaf  2012     12      30.0      15.8         0
# 443        Teknaf  2013     12      29.9      16.5         0
#
#      Relative Humidity  Wind Speed  Cloud Coverage  Bright Sunshine  \
# 0                   60         1.5             0.3              9.7
# ...

# %%
sales['Max Temp'].describe()
# Out:
# count    444.000000
# mean      32.789640
# std        1.773922
# min       27.900000
# 25%       32.000000
# 50%       33.000000
# 75%       34.000000
# max       38.000000
# Name: Max Temp, dtype: float64

# %%
sales.head(5)

# %%
sales.tail(6)

# %%
sales.shape

# %%
sales['Max Temp'].mean()

# %%
sales['Unit Cost'].median()

# %%
sales['Max Temp'].plot(kind='density',figsize= (14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sales['Max Temp'].plot(kind='hist',figsize= (14,6), color= 'green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ax= sales['Max Temp'].plot(kind='density',figsize= (14,6))

# %%
ax= sales['Max Temp'].plot(kind='density',figsize= (14,6))
ax.set_xlabel('Total money')
ax.set_ylabel('Number of sales')

# %%
sales['Max Temp'].plot(kind='pie',figsize= (6,6))
# Out:
# <AxesSubplot:ylabel='Max Temp'>

# %%
sales['Max Temp'].describe()
# Out:
# count    10000.000000
# mean      5002.855900
# std       2873.246454
# min          2.000000
# 25%       2530.750000
# 50%       4962.000000
# 75%       7472.000000
# max      10000.000000
# Name: Units Sold, dtype: float64

# %%
sales['Max Temp'].plot(kind='pie',figsize= (6,6))
# Out:
# <AxesSubplot:ylabel='Max Temp'>

# %%
sales['Units Sold'].value_counts().plot(kind='pie',figsize= (6,6)) #color= 'green')
# Out:
# <AxesSubplot:ylabel='Units Sold'>

# %%
sales['Units Sold'].value_counts()
# Out:
# 1770    6
# 5721    6
# 4526    6
# 788     6
# 4659    6
#        ..
# 7016    1
# 9063    1
# 7008    1
# 9055    1
# 2047    1
# Name: Units Sold, Length: 6307, dtype: int64

# %%
ax2 =sales['Units Sold'].value_counts().plot(kind='density',figsize= (14,6), color= 'green')

ax2.set_xlabel("Price")
ax2.set_ylabel("Number")
#ax2.axvline(sales['Units Sold'].mean() , color='Red')
# Out:
# Text(0, 0.5, 'Number')
